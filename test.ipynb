# %%
import nonebot
from nonebot.adapters.telegram import Adapter as TelegramAdapter
import nonebot.drivers
nonebot.init()
app = nonebot.get_asgi()

driver = nonebot.get_driver()
driver.register_adapter(TelegramAdapter)
# Out:
# 02-06 10:40:29 [SUCCESS] nonebot | NoneBot is initializing...
# 02-06 10:40:29 [INFO] nonebot | Current Env: prod

# %%
print(driver.config)
# Out:
# driver='~fastapi+~httpx' host=IPv4Address('127.0.0.1') port=8080 log_level='INFO' api_timeout=30.0 superusers=set() nickname=set() command_start={'/', '!'} command_sep={'.'} session_expire_timeout=datetime.timedelta(seconds=120) telegram_bots=[{'token': '8186306331:AAG31u_a78bZ--9KxKvZFNGA4ScFCNvK2EM'}] se_su=['7525835156'] server_status_enabled=True server_status_truncate=True server_status_only_superusers=False logpile_retention=360 logpile_level='TRACE' saucenao_api_key='970167ac32d14b79f20f0f5c71bfbb8337745d2e' deepseek={'api_key': 'sk-d7223df849cf4c1d8d97c7178c04e932'} openai_api_key='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' setu_path='./data/setu/'

# %%
driver.config.api_timeout
# Out:
# 30.0
